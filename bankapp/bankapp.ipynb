# %%
import shelve
acc1 ={'name':"sahil","bal":"2000","password":"@ok@"}
acc2={"name":"shreya","bal":"30000","password":"@goyal@"}
acc3={"name":"neha","bal":"10000","password":"@12345@"}

db=shelve.open("garg.db")
db["1001"]=acc1
db['1002']=acc2
db["1003"]=acc3
db["last_acc"]="1003"

db.close()

# %%
from getpass import getpass
def main_menu():
    print('1.login')
    print('2.signup')
    print('3.exit')
    ch=input("choose the option")
    if (ch == 1):
        acc_no=input("enter your account no. : ")
        password=getpass("enter your account password : ")
        if login(acc_no,password):
            menu(acc_no)
        else:
            print("password is invalid")
    elif(ch==2):
        signup()
        main_menu()
    elif(ch==3):
        print("****************thank you*********************")
        
    
    else:
        print("thanks for using my bank service")

# %%
def login(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    if data:
        if data.get("password")==password:
            print("login successful")
            return True
        else:
            print("password is invalid")
            return False
    else:
        print("invalid account no")
        return False

# %%
def menu(acc_no):
    print("1.debit")
    print("2.credit")
    print("3.check balance")
    print("4.update password")
    ch=input("enter your choice")
    if ch==4:
        update_password(acc_no)
     
    elif(ch==1):
        acc_no=input("enter your account no")
        password=getpass("enter your password")
        if debit(acc_no,password):
            menu(acc_no)
        else:
            main_menu()
    elif(ch==2):
        acc_no=input("enter your account no")
        password=getpass("enter your password")
        if credit(acc_no,password):
            menu(acc_no) 
        else:
            main_menu()
    elif(ch==3):
        acc_no=input("enter your account no")
        password=getpass("enter your password")
        if check_bal(acc_no,password):
            menu(acc_no)
        else:
            main_menu()

# %%
def update_password(acc_no):
    p1=getpass("enter your password ")
    p2=getpass("verify your password")
    if p1==p2 :
        db=shelve.open("garg.db")
        db[acc_no]["password"]=p1
        print("your password is updated successfully")
        main_menu()
    else:
        print("password does not matched")
        print("try again")
        update_password(acc-no)

# %%
def debit(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,false)
    old_bal=data.get("bal")
    if data:
        if data.get("password") ==password:
            amount=int(input("enter the amount you want to debit"))
            if old_bal>=amount:
                new_bal=old_bal-amount
                print("your old balance is : ",old_bal)
                db[acc_no]["bal"]=new_bal
                print("new balance is : ",new_bal)
                print("balance is updated successfully")
                db.close()
                main_menu
            else:
                print("your balance is unsufficient")
                print("please try again")
                menu(acc-no)
        else:
            print("your password is incorrect")
            main_menu()
    else:
        print("your account no is invalid")

# %%
def credit(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    old_bal=data.get("bal")
    if data:
        if data.get("password")==password:
            amount=int(input("enter thr amount you want to debit"))
            new_bal=amount+old_bal
            print("your old balance is",old_bal)
            db[acc_no]["bal"]=new_bal
            print("your new balance is : ",new_bal)
            print("your balance is update successfully")
            db.close()
            main_menu()
        else:
            print("your password is invalid")
            menu(acc_no)
    else:
        print("your account no is invalid")
        
def check_bal(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    if data:
        if data.get("password")==password:
            balance=data.get("bal")
            print("your account balance is",balance)
        else:
            print("your account password is invalid")
    else:
        print("your account no is invalid")
        
            
def signup ():
    db=shelve.open("garg,db")
    account=db.get("last_acc")
    account=str(account+1)
    db["last_acc"]=account
    name=input("enter youe name")
    password=getpass("enter your password")
    bal=input('enter your balance')
    user={"name":name,"password":password,"bal":bal}
    db[account]=user
    db.close()
    print("user account is created successfully")
    print("your account no is ",account)

# %%
import shelve
acc1 ={'name':"sahil","bal":"2000","password":"@ok@"}
acc2={"name":"shreya","bal":"30000","password":"@goyal@"}
acc3={"name":"neha","bal":"10000","password":"@12345@"}

db=shelve.open("garg.db")
db["1001"]=acc1
db['1002']=acc2
db["1003"]=acc3
db["last_acc"]="1003"

db.close()

from getpass import getpass
def main_menu():
    print('1.login')
    print('2.signup')
    print('3.exit')
    ch=int(input("choose the option"))
    if (ch == 1):
        acc_no=input("enter your account no. : ")
        password=getpass("enter your account password : ")
        if login(acc_no,password):
            menu(acc_no)
        else:
            print("password is invalid")
    elif(ch==2):
        signup()
        main_menu()
    #elif(ch==3):
       # print("****************thank you*********************")
        
    
    else:
        print("thanks for using my bank service")
        
        
        
def login(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    if data:
        if data.get("password")==password:
            print("login successful")
            return True
        else:
            print("password is invalid")
            return False
    else:
        print("invalid account no")
        return False        

    
    
def menu(acc_no):
    print("1.debit")
    print("2.credit")
    print("3.check balance")
    print("4.update password")
    ch=input("enter your choice")
    if ch==4:
        update_password(acc_no)
     
    elif(ch==1):
        acc_no=input("enter your account no")
        pass+++++
    +
    
    +++++++++++++
    ++++++++++++++++++++++++++++++++++word=getpass("enter your password")
        if debit(acc_no,password):
            menu(acc_no)
        else:
            main_menu()
    elif(ch==2):
        acc_no=input("enter your account no")
        password=getpass("enter your password")
        if credit(acc_no,password):
            menu(acc_no) 
        else:
            main_menu()
    elif(ch==3):
        acc_no=input("enter your account no")
        password=getpass("enter your password")
        if check_bal(acc_no,password):
            menu(acc_no)
        else:
            main_menu()
            
            

def update_password(acc_no):
    p1=getpass("enter your password ")
    p2=getpass("verify your password")
    if p1==p2 :
        db=shelve.open("garg.db")
        db[acc_no]["password"]=p1
        print("your password is updated successfully")
        main_menu()
    else:
        print("password does not matched")
        print("try again")
        update_password(acc-no)            
        
        
def debit(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    old_bal=data.get("bal")
    if data:
        if data.get("password") ==password:
            amount=int(input("enter the amount you want to debit"))
            if old_bal>=amount:
                new_bal=old_bal-amount
                print("your old balance is : ",old_bal)
                db[acc_no]["bal"]=new_bal
                print("new balance is : ",new_bal)
                print("balance is updated successfully")
                db.close()
                main_menu
            else:
                print("your balance is unsufficient")
                print("please try again")
                menu(acc-no)
        else:
            print("your password is incorrect")
            main_menu()
    else:
        print("your account no is invalid")
        
        
        
def credit(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    old_bal=data.get("bal")
    if data:
        if data.get("password")==password:
            amount=int(input("enter thr amount you want to debit"))
            new_bal=amount+old_bal
            print("your old balance is",old_bal)
            db[acc_no]["bal"]=new_bal
            print("your new balance is : ",new_bal)
            print("your balance is update successfully")
            db.close()
            main_menu()
        else:
            print("your password is invalid")
            menu(acc_no)
    else:
        print("your account no is invalid")
        
def check_bal(acc_no,password):
    db=shelve.open("garg.db")
    data=db.get(acc_no,False)
    if data:
        if data.get("password")==password:
            balance=data.get("bal")
            print("your account balance is",balance)
        else:
            print("your account password is invalid")
    else:
        print("your account no is invalid")
        
            
def signup ():
    db=shelve.open("garg,db")
    account=db.get("last_acc")
    account=str(account+1)
    db["last_acc"]=account
    name=input("enter youe name")
    password=getpass("enter your password")
    bal=input('enter your balance')
    user={"name":name,"password":password,"bal":bal}
    db[account]=user
    db.close()
    print("user account is created successfully")
    print("your account no is ",account)
      
        
        
main_menu()
# Out:
# 1.login
# 2.signup
# 3.exit
# choose the option1
# enter your account no. : 1001
# enter your account password : ········
# login successful
# 1.debit
# 2.credit
# 3.check balance
# 4.update password
# enter your choice2

# %%
main_menu()
# Out:
# 1.login
# 2.signup
# 3.exit
